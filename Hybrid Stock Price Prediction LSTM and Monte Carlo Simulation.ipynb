# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
# Out:
# 2023-03-23 19:04:42.081025: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # 1- Loading data:
#
# 1- parse_dates=['Date']: This argument tells pandas to parse the 'Date' column as datetime objects, which makes it easier to work with time-series data. By default, pandas will read the 'Date' column as strings, but specifying parse_dates=['Date'] ensures the dates are correctly interpreted and formatted.
#
# 2- index_col='Date': This argument tells pandas to use the 'Date' column as the DataFrame's index. This is particularly useful for time-series data, as it allows for easy slicing and resampling based on time periods. It also ensures that the date information is preserved when performing operations on the DataFrame.
#
# ## Processing
#
# This step is to create a suitable input format for further preprocessing and model training. Let's break down this line into two parts:
#
# 1- data['Close'].values: This extracts the 'Close' column from the DataFrame, which represents the closing stock prices, and converts it into a NumPy array.
#
# 2- .reshape(-1, 1): This reshapes the array to have a single column and as many rows as necessary (indicated by -1). In this case, it is used to ensure that the array has the correct shape for further processing, such as applying the MinMaxScaler.
#
# By reshaping the 'Close' column into an array with a single column, we explicitly represent it as a 2D array, which is the expected input shape for the MinMaxScaler and other preprocessing steps. This also makes it easier to work with the data when preparing the input sequences for the LSTM model.

# %%
data = pd.read_csv('AAPL.csv', parse_dates=['Date'], index_col='Date')
data = data['Close'].values.reshape(-1, 1)

print(data)
# Out:
# [[  7.643214]
#  [  7.656429]
#  [  7.534643]
#  ...
#  [150.470001]
#  [152.589996]
#  [152.990005]]

# %% [markdown]
# # 2- Scale the data:
#
# Apply MinMax scaling or another scaling technique to normalize the data.
#
# scaled_value = (value - min_value) / (max_value - min_value)
#
# where value is the original data point, min_value is the minimum value in the dataset, and max_value is the maximum value in the dataset. The result, scaled_value, is the transformed data point in the range [0, 1].

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)
print(len(scaled_data),scaled_data,scaled_data[300])
# Out:
# 3322 [[0.00447776]
#  [0.00455321]
#  [0.00385789]
#  ...
#  [0.81992691]
#  [0.83203072]
#  [0.83431451]] [0.03293279]

# %% [markdown]
# # 3- Create a dataset of sequences:
#
# Create input/output sequences for training the LSTM model (e.g., use the past 60 days of data to predict the next day's stock price).
#
#
# In this step, we create input/output sequences (pairs) for training the LSTM model. Each input sequence is a sliding window of historical data (e.g., stock prices) with a specified length (lookback), and the corresponding output is the next value in the time series. The model will use these input/output pairs to learn the patterns in the historical data and make predictions for future data points.

# %%
lookback = 60
X = []
y = []

for i in range(lookback, len(scaled_data)):
    X.append(scaled_data[i-lookback:i,0])
    y.append(scaled_data[i,0])

    
X,y = np.array(X), np.array(y)

X = X.reshape(X.shape[0],X.shape[1],1)      #The purpose of this command is to reshape the input array X into 
                                            #a 3-dimensional array, (number_of_sequences, sequence_length, 
                                            #number_of_features), where number_of_features is 1 since we are 
                                            #only using the closing stock prices.

# %% [markdown]
# In summary, LSTM models expect 3-dimensional input arrays with the shape (batch_size, timesteps, features). A 2-dimensional input array must be reshaped to meet these requirements before being fed into an LSTM model.

# %% [markdown]
# # 4- Split the data into training and test sets:
#
# Divide the preprocessed data into training and test sets, typically using a 80/20 or 70/30 split.

# %%
train_size = int(0.8*len(X))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %% [markdown]
# # 5- Build the LSTM model:
# Define the LSTM model architecture using TensorFlow, including the LSTM layers, Dense layers, and other necessary configurations.
#
# The key components of an LSTM model include:
#
# 1- Memory cells: These cells store information about past inputs, allowing the model to maintain and update its internal state as it processes the input sequence. Memory cells help the LSTM model to capture long-term dependencies and learn from historical data.
#
# 2- Gates: LSTMs have three types of gates that control the flow of information in the model:
#
#     Input gate: Determines which new information should be stored in the memory cell.
#     Forget gate: Decides which information from the memory cell should be forgotten or discarded.
#     Output gate: Decides which information from the memory cell should be used as the current output.
# These gates use sigmoid activation functions to output values between 0 and 1, indicating the proportion of information that should be allowed to pass through.
#
# In summary, an LSTM model is a type of RNN that can effectively learn and remember patterns in sequential data. It uses memory cells and gates to store and manage information, making it capable of capturing long-term dependencies and handling tasks involving time series and sequence data.

# %%
model = Sequential([
    LSTM(100, return_sequences=True, input_shape=(X_train.shape[1], 1)),
    Dropout(0.2),
    LSTM(100, return_sequences=True),
    Dropout(0.2),
    Dense(1)
])
# Out:
# 2023-03-23 19:04:47.568696: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # 6- Compile the model:
# Compile the LSTM model with an optimizer (e.g., 'adam') and a loss function (e.g., 'mean_squared_error').
#
# ## Adam (Adaptive Moment Estimation):
# It is an optimization algorithm used for training neural networks. It combines the best properties of two other popular optimization algorithms: AdaGrad and RMSProp. Adam computes adaptive learning rates for each parameter, which helps the model converge faster and more efficiently.
#
# The main features of the Adam optimizer include:
#
#     1-Adaptive learning rate: It adjusts the learning rate for each parameter individually based on the history of gradients, which helps the optimization to be more efficient.
#     2-Momentum: It incorporates the moving average of the gradients to speed up the convergence, especially in the presence of noisy gradients or sparse data.
#     3-Second-order moment: It uses the moving average of the squared gradients to scale the learning rate, which helps in overcoming issues like vanishing and exploding gradients.
#
# ## Loss Function: Mean Squared Error (MSE)
#
# Mean Squared Error (MSE) is a common loss function used for regression problems, including time series forecasting. It measures the average squared difference between the predicted values and the actual (true) values. The objective of the model training is to minimize this loss function.
#
# MSE is calculated as follows:
#
# MSE = (1/n) * Σ(y_true - y_pred)^2
#
# where y_true represents the actual (true) values, y_pred represents the predicted values, and n is the number of data points.
#
# MSE has some desirable properties for training regression models:
#
#     1- It is continuous and differentiable, which is essential for gradient-based optimization algorithms like Adam.
#     2- It penalizes large errors more severely than small errors, which encourages the model to be more accurate in its predictions.
#     3- It is easy to interpret and has the same unit as the input data squared.

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %% [markdown]
# # 7- Train the model:
# Train the LSTM model on the training data for a specified number of epochs and batch size.
#
# This code fits the model on the training data (X_train, y_train) for 100 epochs with a batch size of 32. It also sets aside 10% of the training data for validation during training.

# %%
history = model.fit(
    X_train, y_train,
    epochs=100,          #The number of times the model will iterate through the entire training dataset.
    batch_size=32,       #The number of samples that will be propagated through the network at each weight update.  
    validation_split=0.1,#The fraction of the training data to be used as validation data. 
    verbose=2            #verbose=1 will show output bars and verbose=0 will not display output bars as progress of
                         #each epoch.
)
# Out:
# Epoch 1/100
# 74/74 - 10s - loss: 0.0057 - val_loss: 0.0761 - 10s/epoch - 139ms/step
# Epoch 2/100
# 74/74 - 7s - loss: 0.0051 - val_loss: 0.0695 - 7s/epoch - 91ms/step
# Epoch 3/100
# 74/74 - 6s - loss: 0.0050 - val_loss: 0.0722 - 6s/epoch - 84ms/step
# Epoch 4/100
# 74/74 - 6s - loss: 0.0050 - val_loss: 0.0722 - 6s/epoch - 78ms/step
# Epoch 5/100
# 74/74 - 6s - loss: 0.0050 - val_loss: 0.0698 - 6s/epoch - 82ms/step
# Epoch 6/100
# 74/74 - 6s - loss: 0.0050 - val_loss: 0.0666 - 6s/epoch - 78ms/step
# Epoch 7/100
# 74/74 - 6s - loss: 0.0050 - val_loss: 0.0684 - 6s/epoch - 78ms/step
# Epoch 8/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0643 - 6s/epoch - 77ms/step
# Epoch 9/100
# 74/74 - 6s - loss: 0.0050 - val_loss: 0.0676 - 6s/epoch - 78ms/step
# Epoch 10/100
# 74/74 - 6s - loss: 0.0050 - val_loss: 0.0642 - 6s/epoch - 78ms/step
# Epoch 11/100
# 74/74 - 6s - loss: 0.0050 - val_loss: 0.0730 - 6s/epoch - 80ms/step
# Epoch 12/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0689 - 6s/epoch - 82ms/step
# Epoch 13/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0701 - 6s/epoch - 81ms/step
# Epoch 14/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0693 - 6s/epoch - 80ms/step
# Epoch 15/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0731 - 6s/epoch - 82ms/step
# Epoch 16/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0696 - 6s/epoch - 86ms/step
# Epoch 17/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0652 - 6s/epoch - 86ms/step
# Epoch 18/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0676 - 6s/epoch - 80ms/step
# Epoch 19/100
# 74/74 - 6s - loss: 0.0050 - val_loss: 0.0707 - 6s/epoch - 80ms/step
# Epoch 20/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0690 - 6s/epoch - 80ms/step
# Epoch 21/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0630 - 6s/epoch - 79ms/step
# Epoch 22/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0718 - 6s/epoch - 79ms/step
# Epoch 23/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0680 - 6s/epoch - 79ms/step
# Epoch 24/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0684 - 6s/epoch - 81ms/step
# Epoch 25/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0714 - 6s/epoch - 79ms/step
# Epoch 26/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0692 - 6s/epoch - 81ms/step
# Epoch 27/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0698 - 6s/epoch - 79ms/step
# Epoch 28/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0716 - 6s/epoch - 80ms/step
# Epoch 29/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0703 - 6s/epoch - 79ms/step
# Epoch 30/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0716 - 6s/epoch - 81ms/step
# Epoch 31/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0672 - 6s/epoch - 81ms/step
# Epoch 32/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0703 - 6s/epoch - 82ms/step
# Epoch 33/100
# 74/74 - 7s - loss: 0.0049 - val_loss: 0.0689 - 7s/epoch - 94ms/step
# Epoch 34/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0719 - 6s/epoch - 83ms/step
# Epoch 35/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0687 - 6s/epoch - 81ms/step
# Epoch 36/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0663 - 6s/epoch - 85ms/step
# Epoch 37/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0711 - 6s/epoch - 85ms/step
# Epoch 38/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0681 - 6s/epoch - 83ms/step
# Epoch 39/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0680 - 6s/epoch - 81ms/step
# Epoch 40/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0688 - 6s/epoch - 80ms/step
# Epoch 41/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0682 - 6s/epoch - 81ms/step
# Epoch 42/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0706 - 6s/epoch - 81ms/step
# Epoch 43/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0674 - 6s/epoch - 81ms/step
# Epoch 44/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0716 - 6s/epoch - 79ms/step
# Epoch 45/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0719 - 6s/epoch - 82ms/step
# Epoch 46/100
# 74/74 - 7s - loss: 0.0049 - val_loss: 0.0661 - 7s/epoch - 88ms/step
# Epoch 47/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0682 - 6s/epoch - 78ms/step
# Epoch 48/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0667 - 6s/epoch - 81ms/step
# Epoch 49/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0677 - 6s/epoch - 79ms/step
# Epoch 50/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0661 - 6s/epoch - 80ms/step
# Epoch 51/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0671 - 6s/epoch - 81ms/step
# Epoch 52/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0696 - 6s/epoch - 78ms/step
# Epoch 53/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0707 - 6s/epoch - 80ms/step
# Epoch 54/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0676 - 6s/epoch - 80ms/step
# Epoch 55/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0693 - 6s/epoch - 80ms/step
# Epoch 56/100
# 74/74 - 7s - loss: 0.0049 - val_loss: 0.0703 - 7s/epoch - 89ms/step
# Epoch 57/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0718 - 6s/epoch - 82ms/step
# Epoch 58/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0695 - 6s/epoch - 84ms/step
# Epoch 59/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0695 - 6s/epoch - 84ms/step
# Epoch 60/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0696 - 6s/epoch - 82ms/step
# Epoch 61/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0708 - 6s/epoch - 80ms/step
# Epoch 62/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0690 - 6s/epoch - 83ms/step
# Epoch 63/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0722 - 6s/epoch - 80ms/step
# Epoch 64/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0697 - 6s/epoch - 82ms/step
# Epoch 65/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0704 - 6s/epoch - 79ms/step
# Epoch 66/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0691 - 6s/epoch - 83ms/step
# Epoch 67/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0683 - 6s/epoch - 85ms/step
# Epoch 68/100
# 74/74 - 7s - loss: 0.0049 - val_loss: 0.0690 - 7s/epoch - 94ms/step
# Epoch 69/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0676 - 6s/epoch - 83ms/step
# Epoch 70/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0667 - 6s/epoch - 83ms/step
# Epoch 71/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0711 - 6s/epoch - 80ms/step
# Epoch 72/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0683 - 6s/epoch - 78ms/step
# Epoch 73/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0688 - 6s/epoch - 80ms/step
# Epoch 74/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0687 - 6s/epoch - 79ms/step
# Epoch 75/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0726 - 6s/epoch - 82ms/step
# Epoch 76/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0714 - 6s/epoch - 78ms/step
# Epoch 77/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0687 - 6s/epoch - 82ms/step
# Epoch 78/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0671 - 6s/epoch - 78ms/step
# Epoch 79/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0688 - 6s/epoch - 80ms/step
# Epoch 80/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0706 - 6s/epoch - 81ms/step
# Epoch 81/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0694 - 6s/epoch - 81ms/step
# Epoch 82/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0708 - 6s/epoch - 81ms/step
# Epoch 83/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0701 - 6s/epoch - 80ms/step
# Epoch 84/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0691 - 6s/epoch - 80ms/step
# Epoch 85/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0692 - 6s/epoch - 81ms/step
# Epoch 86/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0694 - 6s/epoch - 83ms/step
# Epoch 87/100
# 74/74 - 7s - loss: 0.0049 - val_loss: 0.0699 - 7s/epoch - 95ms/step
# Epoch 88/100
# 74/74 - 7s - loss: 0.0049 - val_loss: 0.0669 - 7s/epoch - 95ms/step
# Epoch 89/100
# 74/74 - 7s - loss: 0.0049 - val_loss: 0.0724 - 7s/epoch - 94ms/step
# Epoch 90/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0706 - 6s/epoch - 83ms/step
# Epoch 91/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0662 - 6s/epoch - 78ms/step
# Epoch 92/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0708 - 6s/epoch - 79ms/step
# Epoch 93/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0684 - 6s/epoch - 78ms/step
# Epoch 94/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0683 - 6s/epoch - 78ms/step
# Epoch 95/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0699 - 6s/epoch - 77ms/step
# Epoch 96/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0677 - 6s/epoch - 78ms/step
# Epoch 97/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0676 - 6s/epoch - 77ms/step
# Epoch 98/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0696 - 6s/epoch - 79ms/step
# Epoch 99/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0698 - 6s/epoch - 77ms/step
# Epoch 100/100
# 74/74 - 6s - loss: 0.0049 - val_loss: 0.0681 - 6s/epoch - 79ms/step

# %% [markdown]
# # 8- Evaluate the model:
# Use the trained LSTM model to make predictions on the test dataset, and compare the predictions with the actual stock prices.

# %%
predictions = model.predict(X_test)
predictions = predictions[:, -1, 0]       #you can take the last prediction for each sample:
predictions = predictions.reshape(-1, 1)  # Reshape to (653, 1) before inverse transforming
predictions = scaler.inverse_transform(predictions)
predictions = predictions.ravel()        # Flatten the array back to shape (653,)

actual_prices = y_test.reshape(-1, 1)  # Reshape to (num_samples, 1) before inverse transforming
actual_prices = scaler.inverse_transform(actual_prices)
actual_prices = actual_prices.ravel()  # Flatten the array back to shape (num_samples,)

print(len(predictions), len(y_test))
np.shape(predictions)
# Out:
# 21/21 [==============================] - 1s 25ms/step
# 653 653
# (653,)

# %% [markdown]
# # 9- Visualize the results:
# Plot the predicted and actual stock prices to visualize the model's performance.

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(12, 6))
plt.plot(actual_prices, label='Actual Prices', color='blue')
#plt.plot(predictions, label='Predicted Prices', color='red', linestyle='--')
plt.title('Actual vs Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()


plt.figure(figsize=(12, 6))
#plt.plot(actual_prices, label='Actual Prices', color='blue')
plt.plot(predictions, label='Predicted Prices', color='red', linestyle='--')
plt.title('Actual vs Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# # 10- Model Performance:
# There are several metrics to measure the error between the actual prices and the predictions. Some of the most common metrics for regression problems like this are Mean Squared Error (MSE), Mean Absolute Error (MAE), and Root Mean Squared Error (RMSE).
#
# These error metrics provide different perspectives on the prediction errors:
#
#     MSE: Measures the average squared difference between the predicted and actual values. It gives higher weight to larger errors, making it more sensitive to outliers.
#     MAE: Measures the average absolute difference between the predicted and actual values. It is less sensitive to outliers than MSE.
#     RMSE: Represents the square root of the MSE. It has the same units as the predicted and actual values, making it easier to interpret than MSE. Like MSE, it is sensitive to outliers.
#
# By evaluating these error metrics, you can get an understanding of the model's performance and compare it with other models.

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

mse = mean_squared_error(actual_prices, predictions)
mae = mean_absolute_error(actual_prices, predictions)
rmse = np.sqrt(mse)

print(f"Mean Squared Error: {mse:.2f}")
print(f"Mean Absolute Error: {mae:.2f}")
print(f"Root Mean Squared Error: {rmse:.2f}")
# Out:
# Mean Squared Error: 13194.42
# Mean Absolute Error: 113.59
# Root Mean Squared Error: 114.87

# %% [markdown]
# Interpreting the error values depends on the context and the scale of the actual stock prices. To better understand if these error values are too large, you can calculate the relative errors by comparing them to the range or the mean of the actual stock prices.
#
# Here's how you can calculate the relative errors:

# %%
actual_prices_range = actual_prices.max() - actual_prices.min()
actual_prices_mean = actual_prices.mean()

relative_mse = mse / (actual_prices_range**2)
relative_mae = mae / actual_prices_range
relative_rmse = rmse / actual_prices_range

relative_mae_percentage = (mae / actual_prices_mean) * 100
relative_rmse_percentage = (rmse / actual_prices_mean) * 100

print(f"Relative Mean Squared Error: {relative_mse:.4f}")
print(f"Relative Mean Absolute Error: {relative_mae:.4f}")
print(f"Relative Root Mean Squared Error: {relative_rmse:.4f}")
print(f"Relative Mean Absolute Error (percentage): {relative_mae_percentage:.2f}%")
print(f"Relative Root Mean Squared Error (percentage): {relative_rmse_percentage:.2f}%")
# Out:
# Relative Mean Squared Error: 2.3351
# Relative Mean Absolute Error: 1.5112
# Relative Root Mean Squared Error: 1.5281
# Relative Mean Absolute Error (percentage): 79.30%
# Relative Root Mean Squared Error (percentage): 80.18%

# %% [markdown]
# # 11- Improving Model by Adding More Layer to Network:

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
model_n = Sequential()

# First LSTM layer
model_n.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model_n.add(Dropout(0.2))

# Second LSTM layer
model_n.add(LSTM(units=50, return_sequences=True))
model_n.add(Dropout(0.2))

# Third LSTM layer
model_n.add(LSTM(units=50))
model_n.add(Dropout(0.2))

# Output layer
model_n.add(Dense(units=1))

# %%
from tensorflow.keras.optimizers import Adam

learning_rate = 0.0001  # You can set the desired learning rate value here

optimizer = Adam(lr=learning_rate)

# Compile the model with the custom learning rate
model.compile(optimizer=optimizer, loss='mean_squared_error')
# Out:
# /Users/jawadzafar/anaconda3/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
model_n.compile(optimizer='adam', loss='mean_squared_error')
history_n = model_n.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.1, verbose=2)
# Out:
# Epoch 1/100
# 74/74 - 10s - loss: 0.0012 - val_loss: 8.7833e-04 - 10s/epoch - 131ms/step
# Epoch 2/100
# 74/74 - 4s - loss: 2.1550e-04 - val_loss: 0.0015 - 4s/epoch - 59ms/step
# Epoch 3/100
# 74/74 - 4s - loss: 2.1431e-04 - val_loss: 0.0015 - 4s/epoch - 59ms/step
# Epoch 4/100
# 74/74 - 4s - loss: 1.8431e-04 - val_loss: 0.0011 - 4s/epoch - 59ms/step
# Epoch 5/100
# 74/74 - 4s - loss: 1.6206e-04 - val_loss: 9.9895e-04 - 4s/epoch - 59ms/step
# Epoch 6/100
# 74/74 - 4s - loss: 1.6461e-04 - val_loss: 0.0014 - 4s/epoch - 59ms/step
# Epoch 7/100
# 74/74 - 4s - loss: 1.6200e-04 - val_loss: 6.2232e-04 - 4s/epoch - 59ms/step
# Epoch 8/100
# 74/74 - 5s - loss: 1.4015e-04 - val_loss: 9.6582e-04 - 5s/epoch - 71ms/step
# Epoch 9/100
# 74/74 - 4s - loss: 1.4091e-04 - val_loss: 0.0012 - 4s/epoch - 58ms/step
# Epoch 10/100
# 74/74 - 4s - loss: 1.2067e-04 - val_loss: 8.3628e-04 - 4s/epoch - 59ms/step
# Epoch 11/100
# 74/74 - 4s - loss: 1.1898e-04 - val_loss: 0.0011 - 4s/epoch - 59ms/step
# Epoch 12/100
# 74/74 - 4s - loss: 1.1289e-04 - val_loss: 8.5250e-04 - 4s/epoch - 59ms/step
# Epoch 13/100
# 74/74 - 4s - loss: 1.0104e-04 - val_loss: 4.2861e-04 - 4s/epoch - 59ms/step
# Epoch 14/100
# 74/74 - 4s - loss: 1.2071e-04 - val_loss: 7.8374e-04 - 4s/epoch - 59ms/step
# Epoch 15/100
# 74/74 - 4s - loss: 9.1634e-05 - val_loss: 3.9451e-04 - 4s/epoch - 59ms/step
# Epoch 16/100
# 74/74 - 4s - loss: 1.0408e-04 - val_loss: 4.1247e-04 - 4s/epoch - 59ms/step
# Epoch 17/100
# 74/74 - 4s - loss: 9.5175e-05 - val_loss: 5.3398e-04 - 4s/epoch - 59ms/step
# Epoch 18/100
# 74/74 - 4s - loss: 9.0881e-05 - val_loss: 3.7554e-04 - 4s/epoch - 59ms/step
# Epoch 19/100
# 74/74 - 4s - loss: 9.1290e-05 - val_loss: 3.5140e-04 - 4s/epoch - 59ms/step
# Epoch 20/100
# 74/74 - 4s - loss: 8.3291e-05 - val_loss: 0.0011 - 4s/epoch - 59ms/step
# Epoch 21/100
# 74/74 - 4s - loss: 8.8998e-05 - val_loss: 4.6657e-04 - 4s/epoch - 59ms/step
# Epoch 22/100
# 74/74 - 4s - loss: 8.9115e-05 - val_loss: 3.9298e-04 - 4s/epoch - 59ms/step
# Epoch 23/100
# 74/74 - 4s - loss: 8.4400e-05 - val_loss: 5.7418e-04 - 4s/epoch - 58ms/step
# Epoch 24/100
# 74/74 - 4s - loss: 8.3555e-05 - val_loss: 4.1987e-04 - 4s/epoch - 58ms/step
# Epoch 25/100
# 74/74 - 4s - loss: 8.1280e-05 - val_loss: 5.4740e-04 - 4s/epoch - 58ms/step
# Epoch 26/100
# 74/74 - 4s - loss: 7.8222e-05 - val_loss: 8.0221e-04 - 4s/epoch - 58ms/step
# Epoch 27/100
# 74/74 - 4s - loss: 7.8196e-05 - val_loss: 3.5352e-04 - 4s/epoch - 58ms/step
# Epoch 28/100
# 74/74 - 4s - loss: 7.3222e-05 - val_loss: 7.0283e-04 - 4s/epoch - 59ms/step
# Epoch 29/100
# 74/74 - 4s - loss: 7.1720e-05 - val_loss: 8.3735e-04 - 4s/epoch - 59ms/step
# Epoch 30/100
# 74/74 - 4s - loss: 7.3539e-05 - val_loss: 3.0961e-04 - 4s/epoch - 59ms/step
# Epoch 31/100
# 74/74 - 4s - loss: 8.2817e-05 - val_loss: 8.0763e-04 - 4s/epoch - 59ms/step
# Epoch 32/100
# 74/74 - 4s - loss: 7.2027e-05 - val_loss: 5.9422e-04 - 4s/epoch - 59ms/step
# Epoch 33/100
# 74/74 - 4s - loss: 7.1415e-05 - val_loss: 3.7100e-04 - 4s/epoch - 59ms/step
# Epoch 34/100
# 74/74 - 4s - loss: 7.5396e-05 - val_loss: 4.1491e-04 - 4s/epoch - 59ms/step
# Epoch 35/100
# 74/74 - 4s - loss: 7.2741e-05 - val_loss: 0.0011 - 4s/epoch - 59ms/step
# Epoch 36/100
# 74/74 - 4s - loss: 7.8106e-05 - val_loss: 9.5177e-04 - 4s/epoch - 58ms/step
# Epoch 37/100
# 74/74 - 5s - loss: 8.6808e-05 - val_loss: 5.2776e-04 - 5s/epoch - 63ms/step
# Epoch 38/100
# 74/74 - 5s - loss: 6.6996e-05 - val_loss: 4.4308e-04 - 5s/epoch - 67ms/step
# Epoch 39/100
# 74/74 - 6s - loss: 7.4811e-05 - val_loss: 3.0165e-04 - 6s/epoch - 79ms/step
# Epoch 40/100
# 74/74 - 8s - loss: 6.3304e-05 - val_loss: 3.2038e-04 - 8s/epoch - 103ms/step
# Epoch 41/100
# 74/74 - 6s - loss: 7.3359e-05 - val_loss: 2.6573e-04 - 6s/epoch - 77ms/step
# Epoch 42/100
# 74/74 - 5s - loss: 6.6634e-05 - val_loss: 3.4247e-04 - 5s/epoch - 67ms/step
# Epoch 43/100
# 74/74 - 6s - loss: 6.9709e-05 - val_loss: 3.3466e-04 - 6s/epoch - 77ms/step
# Epoch 44/100
# 74/74 - 5s - loss: 7.1622e-05 - val_loss: 3.0117e-04 - 5s/epoch - 67ms/step
# Epoch 45/100
# 74/74 - 5s - loss: 6.3731e-05 - val_loss: 2.7368e-04 - 5s/epoch - 69ms/step
# Epoch 46/100
# 74/74 - 5s - loss: 7.4264e-05 - val_loss: 4.0733e-04 - 5s/epoch - 67ms/step
# Epoch 47/100
# 74/74 - 5s - loss: 6.8066e-05 - val_loss: 3.2514e-04 - 5s/epoch - 65ms/step
# Epoch 48/100
# 74/74 - 5s - loss: 6.7072e-05 - val_loss: 3.0370e-04 - 5s/epoch - 69ms/step
# Epoch 49/100
# 74/74 - 5s - loss: 6.2754e-05 - val_loss: 5.8180e-04 - 5s/epoch - 65ms/step
# Epoch 50/100
# 74/74 - 5s - loss: 6.7190e-05 - val_loss: 5.9542e-04 - 5s/epoch - 70ms/step
# Epoch 51/100
# 74/74 - 4s - loss: 7.0437e-05 - val_loss: 2.2622e-04 - 4s/epoch - 59ms/step
# Epoch 52/100
# 74/74 - 5s - loss: 7.5064e-05 - val_loss: 2.6861e-04 - 5s/epoch - 61ms/step
# Epoch 53/100
# 74/74 - 4s - loss: 5.7707e-05 - val_loss: 2.8946e-04 - 4s/epoch - 60ms/step
# Epoch 54/100
# 74/74 - 4s - loss: 6.1306e-05 - val_loss: 3.1564e-04 - 4s/epoch - 60ms/step
# Epoch 55/100
# 74/74 - 4s - loss: 7.1803e-05 - val_loss: 2.0552e-04 - 4s/epoch - 59ms/step
# Epoch 56/100
# 74/74 - 5s - loss: 7.6159e-05 - val_loss: 3.2477e-04 - 5s/epoch - 61ms/step
# Epoch 57/100
# 74/74 - 4s - loss: 6.4457e-05 - val_loss: 3.1198e-04 - 4s/epoch - 59ms/step
# Epoch 58/100
# 74/74 - 4s - loss: 6.0921e-05 - val_loss: 3.9347e-04 - 4s/epoch - 61ms/step
# Epoch 59/100
# 74/74 - 5s - loss: 7.0575e-05 - val_loss: 2.8906e-04 - 5s/epoch - 66ms/step
# Epoch 60/100
# 74/74 - 5s - loss: 5.6645e-05 - val_loss: 3.5861e-04 - 5s/epoch - 64ms/step
# Epoch 61/100
# 74/74 - 5s - loss: 6.5138e-05 - val_loss: 4.3110e-04 - 5s/epoch - 74ms/step
# Epoch 62/100
# 74/74 - 7s - loss: 7.4204e-05 - val_loss: 2.8438e-04 - 7s/epoch - 91ms/step
# Epoch 63/100
# 74/74 - 5s - loss: 6.5597e-05 - val_loss: 1.9892e-04 - 5s/epoch - 64ms/step
# Epoch 64/100
# 74/74 - 4s - loss: 7.0032e-05 - val_loss: 1.9308e-04 - 4s/epoch - 59ms/step
# Epoch 65/100
# 74/74 - 4s - loss: 5.8585e-05 - val_loss: 2.3082e-04 - 4s/epoch - 60ms/step
# Epoch 66/100
# 74/74 - 5s - loss: 6.5872e-05 - val_loss: 2.5825e-04 - 5s/epoch - 63ms/step
# Epoch 67/100
# 74/74 - 5s - loss: 6.3769e-05 - val_loss: 1.8685e-04 - 5s/epoch - 62ms/step
# Epoch 68/100
# 74/74 - 5s - loss: 6.3010e-05 - val_loss: 1.8403e-04 - 5s/epoch - 62ms/step
# Epoch 69/100
# 74/74 - 5s - loss: 5.8434e-05 - val_loss: 2.7893e-04 - 5s/epoch - 67ms/step
# Epoch 70/100
# 74/74 - 5s - loss: 5.9395e-05 - val_loss: 2.4712e-04 - 5s/epoch - 73ms/step
# Epoch 71/100
# 74/74 - 6s - loss: 6.5681e-05 - val_loss: 3.1797e-04 - 6s/epoch - 85ms/step
# Epoch 72/100
# 74/74 - 5s - loss: 6.6142e-05 - val_loss: 6.0528e-04 - 5s/epoch - 65ms/step
# Epoch 73/100
# 74/74 - 5s - loss: 6.3903e-05 - val_loss: 1.8449e-04 - 5s/epoch - 64ms/step
# Epoch 74/100
# 74/74 - 4s - loss: 7.3351e-05 - val_loss: 1.7890e-04 - 4s/epoch - 59ms/step
# Epoch 75/100
# 74/74 - 4s - loss: 6.1406e-05 - val_loss: 1.7646e-04 - 4s/epoch - 59ms/step
# Epoch 76/100
# 74/74 - 4s - loss: 6.2997e-05 - val_loss: 2.1960e-04 - 4s/epoch - 59ms/step
# Epoch 77/100
# 74/74 - 4s - loss: 6.3434e-05 - val_loss: 2.4922e-04 - 4s/epoch - 59ms/step
# Epoch 78/100
# 74/74 - 4s - loss: 6.6301e-05 - val_loss: 1.8539e-04 - 4s/epoch - 59ms/step
# Epoch 79/100
# 74/74 - 4s - loss: 6.0447e-05 - val_loss: 2.8505e-04 - 4s/epoch - 59ms/step
# Epoch 80/100
# 74/74 - 4s - loss: 5.7807e-05 - val_loss: 2.5786e-04 - 4s/epoch - 59ms/step
# Epoch 81/100
# 74/74 - 4s - loss: 6.9683e-05 - val_loss: 7.4483e-04 - 4s/epoch - 59ms/step
# Epoch 82/100
# 74/74 - 4s - loss: 6.2285e-05 - val_loss: 2.1560e-04 - 4s/epoch - 59ms/step
# Epoch 83/100
# 74/74 - 4s - loss: 5.6071e-05 - val_loss: 1.7409e-04 - 4s/epoch - 59ms/step
# Epoch 84/100
# 74/74 - 4s - loss: 5.4888e-05 - val_loss: 3.4680e-04 - 4s/epoch - 59ms/step
# Epoch 85/100
# 74/74 - 4s - loss: 5.5922e-05 - val_loss: 1.9833e-04 - 4s/epoch - 61ms/step
# Epoch 86/100
# 74/74 - 4s - loss: 6.1124e-05 - val_loss: 1.7648e-04 - 4s/epoch - 59ms/step
# Epoch 87/100
# 74/74 - 4s - loss: 5.9294e-05 - val_loss: 1.7554e-04 - 4s/epoch - 59ms/step
# Epoch 88/100
# 74/74 - 4s - loss: 5.9969e-05 - val_loss: 1.5836e-04 - 4s/epoch - 59ms/step
# Epoch 89/100
# 74/74 - 4s - loss: 6.0087e-05 - val_loss: 1.6220e-04 - 4s/epoch - 59ms/step
# Epoch 90/100
# 74/74 - 4s - loss: 6.0128e-05 - val_loss: 2.2409e-04 - 4s/epoch - 59ms/step
# Epoch 91/100
# 74/74 - 4s - loss: 5.9775e-05 - val_loss: 1.7391e-04 - 4s/epoch - 60ms/step
# Epoch 92/100
# 74/74 - 4s - loss: 6.0068e-05 - val_loss: 2.1305e-04 - 4s/epoch - 59ms/step
# Epoch 93/100
# 74/74 - 4s - loss: 6.0397e-05 - val_loss: 1.6056e-04 - 4s/epoch - 59ms/step
# Epoch 94/100
# 74/74 - 4s - loss: 5.7841e-05 - val_loss: 3.7432e-04 - 4s/epoch - 59ms/step
# Epoch 95/100
# 74/74 - 4s - loss: 5.7729e-05 - val_loss: 1.5417e-04 - 4s/epoch - 59ms/step
# Epoch 96/100
# 74/74 - 4s - loss: 5.9236e-05 - val_loss: 1.5154e-04 - 4s/epoch - 59ms/step
# Epoch 97/100
# 74/74 - 4s - loss: 5.8028e-05 - val_loss: 1.7117e-04 - 4s/epoch - 59ms/step
# Epoch 98/100
# 74/74 - 4s - loss: 6.4315e-05 - val_loss: 1.6962e-04 - 4s/epoch - 59ms/step
# Epoch 99/100
# 74/74 - 4s - loss: 6.9108e-05 - val_loss: 4.1723e-04 - 4s/epoch - 59ms/step
# Epoch 100/100
# 74/74 - 4s - loss: 6.7310e-05 - val_loss: 1.6349e-04 - 4s/epoch - 59ms/step

# %%
predictions_n = model_n.predict(X_test)
predictions_n = predictions_n[:, -1]  # Take the last prediction for each sample
predictions_n = predictions_n.reshape(-1, 1)  # Reshape to (653, 1) before inverse transforming
predictions_n = scaler.inverse_transform(predictions_n)

#actual_prices_n = y_test.reshape(-1, 1)  # Reshape to (num_samples, 1) before inverse transforming
#actual_prices_n = scaler.inverse_transform(actual_prices_n)
#actual_prices_n = actual_prices_n.ravel()  # Flatten the array back to shape (num_samples,)
# Out:
# 21/21 [==============================] - 2s 19ms/step

# %%
plt.figure(figsize=(12, 6))
plt.plot(actual_prices, label='Actual Prices', color='blue')
plt.plot(predictions_n, label='Predicted Prices', color='red', linestyle='--')
plt.title('Actual vs Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
mse = mean_squared_error(actual_prices, predictions_n)
mae = mean_absolute_error(actual_prices, predictions_n)
rmse = np.sqrt(mse)

print(f"Mean Squared Error: {mse:.2f}")
print(f"Mean Absolute Error: {mae:.2f}")
print(f"Root Mean Squared Error: {rmse:.2f}")

actual_prices_range = actual_prices.max() - actual_prices.min()
actual_prices_mean = actual_prices.mean()

relative_mse = mse / (actual_prices_range**2)
relative_mae = mae / actual_prices_range
relative_rmse = rmse / actual_prices_range

relative_mae_percentage = (mae / actual_prices_mean) * 100
relative_rmse_percentage = (rmse / actual_prices_mean) * 100

print(f"Relative Mean Squared Error: {relative_mse:.4f}")
print(f"Relative Mean Absolute Error: {relative_mae:.4f}")
print(f"Relative Root Mean Squared Error: {relative_rmse:.4f}")
print(f"Relative Mean Absolute Error (percentage): {relative_mae_percentage:.2f}%")
print(f"Relative Root Mean Squared Error (percentage): {relative_rmse_percentage:.2f}%")
# Out:
# Mean Squared Error: 12.95
# Mean Absolute Error: 2.77
# Root Mean Squared Error: 3.60
# Relative Mean Squared Error: 0.0023
# Relative Mean Absolute Error: 0.0368
# Relative Root Mean Squared Error: 0.0479
# Relative Mean Absolute Error (percentage): 1.93%
# Relative Root Mean Squared Error (percentage): 2.51%

# %% [markdown]
# ## Comparison of Both Models:

# %%
date_data = pd.read_csv('AAPL.csv', parse_dates=['Date'], index_col='Date')

train_len = len(X_train) + lookback

test_dates = date_data.index[train_len:]

print()

# %%
plt.figure(figsize=(16, 8))
plt.plot(test_dates, actual_prices, label='Actual Price')
plt.plot(test_dates, predictions, label='Predicted Price (Previous Model)')
plt.plot(test_dates, predictions_n, label='Predicted Price (New Model)')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.title('Stock Price Prediction: Actual vs. Predicted Prices')
plt.legend()
plt.show()

# %% [markdown]
# # Checking for Over fitting:
#
# To ensure that your model is not overfitting,
#
# ## Monitor validation loss:
#
# While training your model, keep track of the validation loss. If the validation loss starts increasing or stagnating while the training loss continues to decrease, it could indicate overfitting. You can modify your model or training process to address this issue.

# %%
# Get training and validation loss values
train_loss_n = history_n.history['loss']
val_loss_n = history_n.history['val_loss']

# Plot the losses over epochs
epochs = range(1, len(train_loss_n) + 1)
plt.plot(epochs, train_loss_n, 'b', label='Training loss')
plt.plot(epochs, val_loss_n, 'r', label='Validation loss')
plt.title('Training and Validation Loss, New Model')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Cross-validation Technique:
#
# Cross-validation is a technique used to assess how well a model generalizes to unseen data. The most common form of cross-validation is k-fold cross-validation. In k-fold cross-validation, the data is divided into k equal-sized folds. The model is then trained on k-1 folds and tested on the remaining fold. This process is repeated k times, with each fold being used as the test set once. The final model performance is calculated as the average performance across all k folds.

# %%
from sklearn.model_selection import TimeSeriesSplit

# %%
tscv = TimeSeriesSplit(n_splits=5)

# %%
mse_scores = []
mae_scores = []
rmse_scores = []

# %%
for train_index, test_index in tscv.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Build and train the LSTM model as you did previously.
    model_cv = Sequential()
    
    # Add LSTM layers, Dropout, and Dense layers as needed.
    model_cv.add(LSTM(units=40, return_sequences=True, input_shape=(X_train.shape[1], 1)))
    model_cv.add(Dropout(0.2))
    
    model_cv.add(LSTM(units=40, return_sequences=True))
    model_cv.add(Dropout(0.2))
    
    model_cv.add(LSTM(units=40, return_sequences=False))
    model_cv.add(Dropout(0.2))
    
    model_cv.add(Dense(units=1))

    # Compile the model and fit it to the training data.
    model_cv.compile(optimizer='adam', loss='mean_squared_error')
    model_cv.fit(X_train, y_train, epochs=100, batch_size=32, verbose=2)

    # Evaluate the model on the test data.
    predictions_cv = model_cv.predict(X_test)
    predictions_cv = scaler.inverse_transform(predictions_cv)
    y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

    mse = mean_squared_error(y_test, predictions_cv)
    mae = mean_absolute_error(y_test, predictions_cv)
    rmse = np.sqrt(mse)

    mse_scores.append(mse)
    mae_scores.append(mae)
    rmse_scores.append(rmse)
# Out:
# Epoch 1/100
# 18/18 - 5s - loss: 4.7959e-04 - 5s/epoch - 290ms/step
# Epoch 2/100
# 18/18 - 1s - loss: 1.4378e-04 - 972ms/epoch - 54ms/step
# Epoch 3/100
# 18/18 - 1s - loss: 5.5201e-05 - 885ms/epoch - 49ms/step
# Epoch 4/100
# 18/18 - 1s - loss: 4.0510e-05 - 879ms/epoch - 49ms/step
# Epoch 5/100
# 18/18 - 1s - loss: 2.9900e-05 - 884ms/epoch - 49ms/step
# Epoch 6/100
# 18/18 - 1s - loss: 3.1944e-05 - 883ms/epoch - 49ms/step
# Epoch 7/100
# 18/18 - 1s - loss: 3.4867e-05 - 873ms/epoch - 48ms/step
# Epoch 8/100
# 18/18 - 1s - loss: 3.7056e-05 - 883ms/epoch - 49ms/step
# Epoch 9/100
# 18/18 - 1s - loss: 3.4167e-05 - 873ms/epoch - 48ms/step
# Epoch 10/100
# 18/18 - 1s - loss: 2.5837e-05 - 900ms/epoch - 50ms/step
# Epoch 11/100
# 18/18 - 1s - loss: 3.2299e-05 - 916ms/epoch - 51ms/step
# Epoch 12/100
# 18/18 - 1s - loss: 2.6305e-05 - 1s/epoch - 58ms/step
# Epoch 13/100
# 18/18 - 1s - loss: 2.3108e-05 - 879ms/epoch - 49ms/step
# Epoch 14/100
# 18/18 - 1s - loss: 2.4939e-05 - 878ms/epoch - 49ms/step
# Epoch 15/100
# 18/18 - 1s - loss: 2.5633e-05 - 877ms/epoch - 49ms/step
# Epoch 16/100
# 18/18 - 1s - loss: 2.7659e-05 - 877ms/epoch - 49ms/step
# Epoch 17/100
# 18/18 - 1s - loss: 2.1174e-05 - 885ms/epoch - 49ms/step
# Epoch 18/100
# 18/18 - 1s - loss: 2.6191e-05 - 875ms/epoch - 49ms/step
# Epoch 19/100
# 18/18 - 1s - loss: 2.0995e-05 - 878ms/epoch - 49ms/step
# Epoch 20/100
# 18/18 - 1s - loss: 2.1854e-05 - 880ms/epoch - 49ms/step
# Epoch 21/100
# 18/18 - 1s - loss: 3.4874e-05 - 879ms/epoch - 49ms/step
# Epoch 22/100
# 18/18 - 1s - loss: 2.4813e-05 - 884ms/epoch - 49ms/step
# Epoch 23/100
# 18/18 - 1s - loss: 2.4037e-05 - 884ms/epoch - 49ms/step
# Epoch 24/100
# 18/18 - 1s - loss: 2.1578e-05 - 878ms/epoch - 49ms/step
# Epoch 25/100
# 18/18 - 1s - loss: 1.7379e-05 - 881ms/epoch - 49ms/step
# Epoch 26/100
# 18/18 - 1s - loss: 1.9136e-05 - 877ms/epoch - 49ms/step
# Epoch 27/100
# 18/18 - 1s - loss: 2.2831e-05 - 886ms/epoch - 49ms/step
# Epoch 28/100
# 18/18 - 1s - loss: 1.8725e-05 - 876ms/epoch - 49ms/step
# Epoch 29/100
# 18/18 - 1s - loss: 1.6540e-05 - 882ms/epoch - 49ms/step
# Epoch 30/100
# 18/18 - 1s - loss: 1.8428e-05 - 888ms/epoch - 49ms/step
# Epoch 31/100
# 18/18 - 1s - loss: 1.8468e-05 - 885ms/epoch - 49ms/step
# Epoch 32/100
# 18/18 - 1s - loss: 1.8222e-05 - 979ms/epoch - 54ms/step
# Epoch 33/100
# 18/18 - 1s - loss: 1.9694e-05 - 876ms/epoch - 49ms/step
# Epoch 34/100
# 18/18 - 1s - loss: 2.6561e-05 - 893ms/epoch - 50ms/step
# Epoch 35/100
# 18/18 - 1s - loss: 1.4747e-05 - 881ms/epoch - 49ms/step
# Epoch 36/100
# 18/18 - 1s - loss: 1.9327e-05 - 873ms/epoch - 49ms/step
# Epoch 37/100
# 18/18 - 1s - loss: 1.6393e-05 - 880ms/epoch - 49ms/step
# Epoch 38/100
# 18/18 - 1s - loss: 1.6303e-05 - 885ms/epoch - 49ms/step
# Epoch 39/100
# 18/18 - 1s - loss: 1.4115e-05 - 877ms/epoch - 49ms/step
# Epoch 40/100
# 18/18 - 1s - loss: 1.6936e-05 - 875ms/epoch - 49ms/step
# Epoch 41/100
# 18/18 - 1s - loss: 1.6311e-05 - 878ms/epoch - 49ms/step
# Epoch 42/100
# 18/18 - 1s - loss: 1.5155e-05 - 924ms/epoch - 51ms/step
# Epoch 43/100
# 18/18 - 1s - loss: 1.6265e-05 - 894ms/epoch - 50ms/step
# Epoch 44/100
# 18/18 - 1s - loss: 2.5685e-05 - 882ms/epoch - 49ms/step
# Epoch 45/100
# 18/18 - 1s - loss: 2.1903e-05 - 874ms/epoch - 49ms/step
# Epoch 46/100
# 18/18 - 1s - loss: 1.9169e-05 - 880ms/epoch - 49ms/step
# Epoch 47/100
# 18/18 - 1s - loss: 1.5639e-05 - 879ms/epoch - 49ms/step
# Epoch 48/100
# 18/18 - 1s - loss: 1.3852e-05 - 905ms/epoch - 50ms/step
# Epoch 49/100
# 18/18 - 1s - loss: 1.6774e-05 - 880ms/epoch - 49ms/step
# Epoch 50/100
# 18/18 - 1s - loss: 1.5452e-05 - 878ms/epoch - 49ms/step
# Epoch 51/100
# 18/18 - 1s - loss: 1.7091e-05 - 878ms/epoch - 49ms/step
# Epoch 52/100
# 18/18 - 1s - loss: 1.5794e-05 - 886ms/epoch - 49ms/step
# Epoch 53/100
# 18/18 - 1s - loss: 1.5143e-05 - 880ms/epoch - 49ms/step
# Epoch 54/100
# 18/18 - 1s - loss: 2.2179e-05 - 885ms/epoch - 49ms/step
# Epoch 55/100
# 18/18 - 1s - loss: 1.7485e-05 - 932ms/epoch - 52ms/step
# Epoch 56/100
# 18/18 - 1s - loss: 2.4872e-05 - 879ms/epoch - 49ms/step
# Epoch 57/100
# 18/18 - 1s - loss: 1.9103e-05 - 874ms/epoch - 49ms/step
# Epoch 58/100
# 18/18 - 1s - loss: 1.7154e-05 - 879ms/epoch - 49ms/step
# Epoch 59/100
# 18/18 - 1s - loss: 1.6471e-05 - 875ms/epoch - 49ms/step
# Epoch 60/100
# 18/18 - 1s - loss: 1.4830e-05 - 877ms/epoch - 49ms/step
# Epoch 61/100
# 18/18 - 1s - loss: 1.3311e-05 - 880ms/epoch - 49ms/step
# Epoch 62/100
# 18/18 - 1s - loss: 1.2345e-05 - 875ms/epoch - 49ms/step
# Epoch 63/100
# 18/18 - 1s - loss: 1.3803e-05 - 880ms/epoch - 49ms/step
# Epoch 64/100
# 18/18 - 1s - loss: 1.7961e-05 - 878ms/epoch - 49ms/step
# Epoch 65/100
# 18/18 - 1s - loss: 1.4492e-05 - 880ms/epoch - 49ms/step
# Epoch 66/100
# 18/18 - 1s - loss: 1.7657e-05 - 871ms/epoch - 48ms/step
# Epoch 67/100
# 18/18 - 1s - loss: 2.3776e-05 - 881ms/epoch - 49ms/step
# Epoch 68/100
# 18/18 - 1s - loss: 1.2207e-05 - 887ms/epoch - 49ms/step
# Epoch 69/100
# 18/18 - 1s - loss: 1.3076e-05 - 884ms/epoch - 49ms/step
# Epoch 70/100
# 18/18 - 1s - loss: 1.4114e-05 - 889ms/epoch - 49ms/step
# Epoch 71/100
# 18/18 - 1s - loss: 1.1887e-05 - 875ms/epoch - 49ms/step
# Epoch 72/100
# 18/18 - 1s - loss: 1.5367e-05 - 922ms/epoch - 51ms/step
# Epoch 73/100
# 18/18 - 1s - loss: 1.7333e-05 - 878ms/epoch - 49ms/step
# Epoch 74/100
# 18/18 - 1s - loss: 1.4720e-05 - 871ms/epoch - 48ms/step
# Epoch 75/100
# 18/18 - 1s - loss: 1.4253e-05 - 880ms/epoch - 49ms/step
# Epoch 76/100
# 18/18 - 1s - loss: 1.3511e-05 - 883ms/epoch - 49ms/step
# Epoch 77/100
# 18/18 - 1s - loss: 1.1786e-05 - 876ms/epoch - 49ms/step
# Epoch 78/100
# 18/18 - 1s - loss: 1.7955e-05 - 950ms/epoch - 53ms/step
# Epoch 79/100
# 18/18 - 1s - loss: 1.6318e-05 - 936ms/epoch - 52ms/step
# Epoch 80/100
# 18/18 - 1s - loss: 1.3328e-05 - 912ms/epoch - 51ms/step
# Epoch 81/100
# 18/18 - 1s - loss: 1.6178e-05 - 892ms/epoch - 50ms/step
# Epoch 82/100
# 18/18 - 1s - loss: 1.2979e-05 - 1s/epoch - 56ms/step
# Epoch 83/100
# 18/18 - 1s - loss: 1.7962e-05 - 1s/epoch - 56ms/step
# Epoch 84/100
# 18/18 - 1s - loss: 1.8897e-05 - 977ms/epoch - 54ms/step
# Epoch 85/100
# 18/18 - 1s - loss: 1.3355e-05 - 896ms/epoch - 50ms/step
# Epoch 86/100
# 18/18 - 1s - loss: 1.1150e-05 - 887ms/epoch - 49ms/step
# Epoch 87/100
# 18/18 - 1s - loss: 1.9414e-05 - 883ms/epoch - 49ms/step
# Epoch 88/100
# 18/18 - 1s - loss: 1.3487e-05 - 880ms/epoch - 49ms/step
# Epoch 89/100
# 18/18 - 1s - loss: 1.2602e-05 - 967ms/epoch - 54ms/step
# Epoch 90/100
# 18/18 - 1s - loss: 1.3140e-05 - 879ms/epoch - 49ms/step
# Epoch 91/100
# 18/18 - 1s - loss: 1.5059e-05 - 1s/epoch - 65ms/step
# Epoch 92/100
# 18/18 - 1s - loss: 1.7131e-05 - 880ms/epoch - 49ms/step
# Epoch 93/100
# 18/18 - 1s - loss: 1.3692e-05 - 888ms/epoch - 49ms/step
# Epoch 94/100
# 18/18 - 1s - loss: 1.4396e-05 - 876ms/epoch - 49ms/step
# Epoch 95/100
# 18/18 - 1s - loss: 1.5543e-05 - 887ms/epoch - 49ms/step
# Epoch 96/100
# 18/18 - 1s - loss: 1.1583e-05 - 875ms/epoch - 49ms/step
# Epoch 97/100
# 18/18 - 1s - loss: 1.2832e-05 - 878ms/epoch - 49ms/step
# Epoch 98/100
# 18/18 - 1s - loss: 1.7027e-05 - 876ms/epoch - 49ms/step
# Epoch 99/100
# 18/18 - 1s - loss: 1.3077e-05 - 876ms/epoch - 49ms/step
# Epoch 100/100
# 18/18 - 1s - loss: 1.2044e-05 - 885ms/epoch - 49ms/step
# 17/17 [==============================] - 1s 15ms/step
# Epoch 1/100
# 35/35 - 6s - loss: 4.8271e-04 - 6s/epoch - 165ms/step
# Epoch 2/100
# 35/35 - 2s - loss: 8.5014e-05 - 2s/epoch - 49ms/step
# Epoch 3/100
# 35/35 - 2s - loss: 5.4152e-05 - 2s/epoch - 49ms/step
# Epoch 4/100
# 35/35 - 2s - loss: 5.3058e-05 - 2s/epoch - 49ms/step
# Epoch 5/100
# 35/35 - 2s - loss: 6.1076e-05 - 2s/epoch - 49ms/step
# Epoch 6/100
# 35/35 - 2s - loss: 4.3272e-05 - 2s/epoch - 49ms/step
# Epoch 7/100
# 35/35 - 2s - loss: 4.3920e-05 - 2s/epoch - 50ms/step
# Epoch 8/100
# 35/35 - 2s - loss: 5.0780e-05 - 2s/epoch - 49ms/step
# Epoch 9/100
# 35/35 - 2s - loss: 3.9963e-05 - 2s/epoch - 49ms/step
# Epoch 10/100
# 35/35 - 2s - loss: 3.9006e-05 - 2s/epoch - 49ms/step
# Epoch 11/100
# 35/35 - 2s - loss: 4.3399e-05 - 2s/epoch - 50ms/step
# Epoch 12/100
# 35/35 - 2s - loss: 3.5447e-05 - 2s/epoch - 50ms/step
# Epoch 13/100
# 35/35 - 2s - loss: 3.2790e-05 - 2s/epoch - 49ms/step
# Epoch 14/100
# 35/35 - 2s - loss: 3.6205e-05 - 2s/epoch - 49ms/step
# Epoch 15/100
# 35/35 - 2s - loss: 3.5510e-05 - 2s/epoch - 49ms/step
# Epoch 16/100
# 35/35 - 2s - loss: 2.9977e-05 - 2s/epoch - 49ms/step
# Epoch 17/100
# 35/35 - 2s - loss: 3.7257e-05 - 2s/epoch - 49ms/step
# Epoch 18/100
# 35/35 - 2s - loss: 3.6999e-05 - 2s/epoch - 50ms/step
# Epoch 19/100
# 35/35 - 2s - loss: 2.9215e-05 - 2s/epoch - 49ms/step
# Epoch 20/100
# 35/35 - 2s - loss: 2.9218e-05 - 2s/epoch - 49ms/step
# Epoch 21/100
# 35/35 - 2s - loss: 3.0032e-05 - 2s/epoch - 49ms/step
# Epoch 22/100
# 35/35 - 2s - loss: 2.5976e-05 - 2s/epoch - 49ms/step
# Epoch 23/100
# 35/35 - 2s - loss: 2.5782e-05 - 2s/epoch - 49ms/step
# Epoch 24/100
# 35/35 - 2s - loss: 3.1899e-05 - 2s/epoch - 49ms/step
# Epoch 25/100
# 35/35 - 2s - loss: 2.4532e-05 - 2s/epoch - 49ms/step
# Epoch 26/100
# 35/35 - 2s - loss: 3.0445e-05 - 2s/epoch - 49ms/step
# Epoch 27/100
# 35/35 - 2s - loss: 3.3804e-05 - 2s/epoch - 49ms/step
# Epoch 28/100
# 35/35 - 2s - loss: 2.3987e-05 - 2s/epoch - 49ms/step
# Epoch 29/100
# 35/35 - 2s - loss: 2.5622e-05 - 2s/epoch - 49ms/step
# Epoch 30/100
# 35/35 - 2s - loss: 2.5754e-05 - 2s/epoch - 49ms/step
# Epoch 31/100
# 35/35 - 2s - loss: 2.6259e-05 - 2s/epoch - 49ms/step
# Epoch 32/100
# 35/35 - 2s - loss: 2.5543e-05 - 2s/epoch - 49ms/step
# Epoch 33/100
# 35/35 - 2s - loss: 2.1938e-05 - 2s/epoch - 49ms/step
# Epoch 34/100
# 35/35 - 2s - loss: 2.3846e-05 - 2s/epoch - 49ms/step
# Epoch 35/100
# 35/35 - 2s - loss: 2.3013e-05 - 2s/epoch - 49ms/step
# Epoch 36/100
# 35/35 - 2s - loss: 2.0404e-05 - 2s/epoch - 49ms/step
# Epoch 37/100
# 35/35 - 2s - loss: 2.2140e-05 - 2s/epoch - 49ms/step
# Epoch 38/100
# 35/35 - 2s - loss: 2.2230e-05 - 2s/epoch - 49ms/step
# Epoch 39/100
# 35/35 - 2s - loss: 2.8355e-05 - 2s/epoch - 49ms/step
# Epoch 40/100
# 35/35 - 2s - loss: 2.5312e-05 - 2s/epoch - 49ms/step
# Epoch 41/100
# 35/35 - 2s - loss: 2.0040e-05 - 2s/epoch - 49ms/step
# Epoch 42/100
# 35/35 - 2s - loss: 2.3834e-05 - 2s/epoch - 49ms/step
# Epoch 43/100
# 35/35 - 2s - loss: 2.0921e-05 - 2s/epoch - 48ms/step
# Epoch 44/100
# 35/35 - 2s - loss: 1.9291e-05 - 2s/epoch - 49ms/step
# Epoch 45/100
# 35/35 - 2s - loss: 2.7382e-05 - 2s/epoch - 49ms/step
# Epoch 46/100
# 35/35 - 2s - loss: 2.0358e-05 - 2s/epoch - 49ms/step
# Epoch 47/100
# 35/35 - 2s - loss: 2.1381e-05 - 2s/epoch - 49ms/step
# Epoch 48/100
# 35/35 - 2s - loss: 1.9835e-05 - 2s/epoch - 49ms/step
# Epoch 49/100
# 35/35 - 2s - loss: 2.2610e-05 - 2s/epoch - 49ms/step
# Epoch 50/100
# 35/35 - 2s - loss: 2.0652e-05 - 2s/epoch - 49ms/step
# Epoch 51/100
# 35/35 - 2s - loss: 2.2632e-05 - 2s/epoch - 50ms/step
# Epoch 52/100
# 35/35 - 2s - loss: 1.8938e-05 - 2s/epoch - 49ms/step
# Epoch 53/100
# 35/35 - 2s - loss: 1.8963e-05 - 2s/epoch - 49ms/step
# Epoch 54/100
# 35/35 - 2s - loss: 1.9127e-05 - 2s/epoch - 49ms/step
# Epoch 55/100
# 35/35 - 2s - loss: 1.9234e-05 - 2s/epoch - 49ms/step
# Epoch 56/100
# 35/35 - 2s - loss: 1.8783e-05 - 2s/epoch - 50ms/step
# Epoch 57/100
# 35/35 - 2s - loss: 1.7518e-05 - 2s/epoch - 49ms/step
# Epoch 58/100
# 35/35 - 2s - loss: 2.0418e-05 - 2s/epoch - 49ms/step
# Epoch 59/100
# 35/35 - 2s - loss: 2.7964e-05 - 2s/epoch - 49ms/step
# Epoch 60/100
# 35/35 - 2s - loss: 2.6316e-05 - 2s/epoch - 49ms/step
# Epoch 61/100
# 35/35 - 2s - loss: 1.9448e-05 - 2s/epoch - 49ms/step
# Epoch 62/100
# 35/35 - 2s - loss: 2.0496e-05 - 2s/epoch - 49ms/step
# Epoch 63/100
# 35/35 - 2s - loss: 2.4316e-05 - 2s/epoch - 49ms/step
# Epoch 64/100
# 35/35 - 2s - loss: 1.9800e-05 - 2s/epoch - 50ms/step
# Epoch 65/100
# 35/35 - 2s - loss: 1.8422e-05 - 2s/epoch - 50ms/step
# Epoch 66/100
# 35/35 - 2s - loss: 1.9113e-05 - 2s/epoch - 50ms/step
# Epoch 67/100
# 35/35 - 2s - loss: 1.8141e-05 - 2s/epoch - 49ms/step
# Epoch 68/100
# 35/35 - 2s - loss: 2.3344e-05 - 2s/epoch - 49ms/step
# Epoch 69/100
# 35/35 - 2s - loss: 1.8507e-05 - 2s/epoch - 49ms/step
# Epoch 70/100
# 35/35 - 2s - loss: 1.7316e-05 - 2s/epoch - 51ms/step
# Epoch 71/100
# 35/35 - 2s - loss: 1.7411e-05 - 2s/epoch - 50ms/step
# Epoch 72/100
# 35/35 - 2s - loss: 1.9613e-05 - 2s/epoch - 51ms/step
# Epoch 73/100
# 35/35 - 2s - loss: 1.7071e-05 - 2s/epoch - 49ms/step
# Epoch 74/100
# 35/35 - 2s - loss: 2.0540e-05 - 2s/epoch - 49ms/step
# Epoch 75/100
# 35/35 - 2s - loss: 1.8712e-05 - 2s/epoch - 49ms/step
# Epoch 76/100
# 35/35 - 2s - loss: 2.5771e-05 - 2s/epoch - 49ms/step
# Epoch 77/100
# 35/35 - 2s - loss: 1.9342e-05 - 2s/epoch - 49ms/step
# Epoch 78/100
# 35/35 - 2s - loss: 1.7065e-05 - 2s/epoch - 50ms/step
# Epoch 79/100
# 35/35 - 2s - loss: 1.7292e-05 - 2s/epoch - 49ms/step
# Epoch 80/100
# 35/35 - 2s - loss: 1.7958e-05 - 2s/epoch - 49ms/step
# Epoch 81/100
# 35/35 - 2s - loss: 1.8868e-05 - 2s/epoch - 50ms/step
# Epoch 82/100
# 35/35 - 2s - loss: 1.7344e-05 - 2s/epoch - 49ms/step
# Epoch 83/100
# 35/35 - 2s - loss: 1.7369e-05 - 2s/epoch - 49ms/step
# Epoch 84/100
# 35/35 - 2s - loss: 1.5944e-05 - 2s/epoch - 49ms/step
# Epoch 85/100
# 35/35 - 2s - loss: 1.5911e-05 - 2s/epoch - 49ms/step
# Epoch 86/100
# 35/35 - 2s - loss: 1.6836e-05 - 2s/epoch - 49ms/step
# Epoch 87/100
# 35/35 - 2s - loss: 1.7170e-05 - 2s/epoch - 49ms/step
# Epoch 88/100
# 35/35 - 2s - loss: 1.6144e-05 - 2s/epoch - 49ms/step
# Epoch 89/100
# 35/35 - 2s - loss: 2.0366e-05 - 2s/epoch - 55ms/step
# Epoch 90/100
# 35/35 - 2s - loss: 2.1884e-05 - 2s/epoch - 49ms/step
# Epoch 91/100
# 35/35 - 2s - loss: 1.8033e-05 - 2s/epoch - 49ms/step
# Epoch 92/100
# 35/35 - 2s - loss: 1.7665e-05 - 2s/epoch - 49ms/step
# Epoch 93/100
# 35/35 - 2s - loss: 2.1483e-05 - 2s/epoch - 49ms/step
# Epoch 94/100
# 35/35 - 2s - loss: 1.7531e-05 - 2s/epoch - 49ms/step
# Epoch 95/100
# 35/35 - 2s - loss: 1.5156e-05 - 2s/epoch - 49ms/step
# Epoch 96/100
# 35/35 - 2s - loss: 1.4864e-05 - 2s/epoch - 49ms/step
# Epoch 97/100
# 35/35 - 2s - loss: 1.8861e-05 - 2s/epoch - 49ms/step
# Epoch 98/100
# 35/35 - 2s - loss: 1.6142e-05 - 2s/epoch - 49ms/step
# Epoch 99/100
# 35/35 - 2s - loss: 1.4901e-05 - 2s/epoch - 49ms/step
# Epoch 100/100
# 35/35 - 2s - loss: 2.0609e-05 - 2s/epoch - 50ms/step
# 17/17 [==============================] - 2s 16ms/step
# Epoch 1/100
# 52/52 - 7s - loss: 7.9654e-04 - 7s/epoch - 127ms/step
# Epoch 2/100
# 52/52 - 3s - loss: 1.0554e-04 - 3s/epoch - 50ms/step
# Epoch 3/100
# 52/52 - 3s - loss: 1.0761e-04 - 3s/epoch - 50ms/step
# Epoch 4/100
# 52/52 - 3s - loss: 9.8198e-05 - 3s/epoch - 50ms/step
# Epoch 5/100
# 52/52 - 3s - loss: 7.5282e-05 - 3s/epoch - 49ms/step
# Epoch 6/100
# 52/52 - 3s - loss: 7.8695e-05 - 3s/epoch - 50ms/step
# Epoch 7/100
# 52/52 - 3s - loss: 7.7254e-05 - 3s/epoch - 50ms/step
# Epoch 8/100
# 52/52 - 3s - loss: 6.3438e-05 - 3s/epoch - 50ms/step
# Epoch 9/100
# 52/52 - 3s - loss: 6.7169e-05 - 3s/epoch - 50ms/step
# Epoch 10/100
# 52/52 - 3s - loss: 5.8689e-05 - 3s/epoch - 51ms/step
# Epoch 11/100
# 52/52 - 3s - loss: 5.8589e-05 - 3s/epoch - 50ms/step
# Epoch 12/100
# 52/52 - 3s - loss: 6.7357e-05 - 3s/epoch - 50ms/step
# Epoch 13/100
# 52/52 - 3s - loss: 5.4809e-05 - 3s/epoch - 50ms/step
# Epoch 14/100
# 52/52 - 3s - loss: 5.1563e-05 - 3s/epoch - 52ms/step
# Epoch 15/100
# 52/52 - 3s - loss: 4.7838e-05 - 3s/epoch - 50ms/step
# Epoch 16/100
# 52/52 - 3s - loss: 5.0400e-05 - 3s/epoch - 50ms/step
# Epoch 17/100
# 52/52 - 3s - loss: 5.4762e-05 - 3s/epoch - 50ms/step
# Epoch 18/100
# 52/52 - 3s - loss: 4.2685e-05 - 3s/epoch - 50ms/step
# Epoch 19/100
# 52/52 - 3s - loss: 4.6712e-05 - 3s/epoch - 50ms/step
# Epoch 20/100
# 52/52 - 3s - loss: 4.0648e-05 - 3s/epoch - 49ms/step
# Epoch 21/100
# 52/52 - 3s - loss: 4.2875e-05 - 3s/epoch - 50ms/step
# Epoch 22/100
# 52/52 - 3s - loss: 5.1679e-05 - 3s/epoch - 50ms/step
# Epoch 23/100
# 52/52 - 3s - loss: 3.5279e-05 - 3s/epoch - 50ms/step
# Epoch 24/100
# 52/52 - 3s - loss: 3.9070e-05 - 3s/epoch - 50ms/step
# Epoch 25/100
# 52/52 - 3s - loss: 3.7659e-05 - 3s/epoch - 51ms/step
# Epoch 26/100
# 52/52 - 3s - loss: 4.2688e-05 - 3s/epoch - 49ms/step
# Epoch 27/100
# 52/52 - 3s - loss: 3.9843e-05 - 3s/epoch - 51ms/step
# Epoch 28/100
# 52/52 - 3s - loss: 7.1899e-05 - 3s/epoch - 57ms/step
# Epoch 29/100
# 52/52 - 3s - loss: 3.7558e-05 - 3s/epoch - 53ms/step
# Epoch 30/100
# 52/52 - 3s - loss: 3.4447e-05 - 3s/epoch - 50ms/step
# Epoch 31/100
# 52/52 - 3s - loss: 3.3250e-05 - 3s/epoch - 50ms/step
# Epoch 32/100
# 52/52 - 3s - loss: 3.4645e-05 - 3s/epoch - 50ms/step
# Epoch 33/100
# 52/52 - 3s - loss: 3.4916e-05 - 3s/epoch - 51ms/step
# Epoch 34/100
# 52/52 - 3s - loss: 3.4996e-05 - 3s/epoch - 50ms/step
# Epoch 35/100
# 52/52 - 3s - loss: 3.6397e-05 - 3s/epoch - 51ms/step
# Epoch 36/100
# 52/52 - 3s - loss: 3.4418e-05 - 3s/epoch - 50ms/step
# Epoch 37/100
# 52/52 - 3s - loss: 3.6433e-05 - 3s/epoch - 50ms/step
# Epoch 38/100
# 52/52 - 3s - loss: 3.5284e-05 - 3s/epoch - 50ms/step
# Epoch 39/100
# 52/52 - 3s - loss: 3.3062e-05 - 3s/epoch - 50ms/step
# Epoch 40/100
# 52/52 - 3s - loss: 3.0636e-05 - 3s/epoch - 50ms/step
# Epoch 41/100
# 52/52 - 3s - loss: 3.6167e-05 - 3s/epoch - 50ms/step
# Epoch 42/100
# 52/52 - 3s - loss: 3.2652e-05 - 3s/epoch - 49ms/step
# Epoch 43/100
# 52/52 - 3s - loss: 3.6391e-05 - 3s/epoch - 50ms/step
# Epoch 44/100
# 52/52 - 3s - loss: 3.5148e-05 - 3s/epoch - 50ms/step
# Epoch 45/100
# 52/52 - 3s - loss: 4.8096e-05 - 3s/epoch - 50ms/step
# Epoch 46/100
# 52/52 - 3s - loss: 3.2643e-05 - 3s/epoch - 50ms/step
# Epoch 47/100
# 52/52 - 3s - loss: 3.2583e-05 - 3s/epoch - 49ms/step
# Epoch 48/100
# 52/52 - 3s - loss: 4.6663e-05 - 3s/epoch - 49ms/step
# Epoch 49/100
# 52/52 - 3s - loss: 4.1740e-05 - 3s/epoch - 50ms/step
# Epoch 50/100
# 52/52 - 3s - loss: 3.0585e-05 - 3s/epoch - 50ms/step
# Epoch 51/100
# 52/52 - 3s - loss: 3.0449e-05 - 3s/epoch - 50ms/step
# Epoch 52/100
# 52/52 - 3s - loss: 2.9656e-05 - 3s/epoch - 50ms/step
# Epoch 53/100
# 52/52 - 3s - loss: 2.9099e-05 - 3s/epoch - 50ms/step
# Epoch 54/100
# 52/52 - 3s - loss: 3.0190e-05 - 3s/epoch - 50ms/step
# Epoch 55/100
# 52/52 - 3s - loss: 3.0843e-05 - 3s/epoch - 50ms/step
# Epoch 56/100
# 52/52 - 3s - loss: 3.6239e-05 - 3s/epoch - 49ms/step
# Epoch 57/100
# 52/52 - 3s - loss: 2.8683e-05 - 3s/epoch - 49ms/step
# Epoch 58/100
# 52/52 - 3s - loss: 3.2005e-05 - 3s/epoch - 51ms/step
# Epoch 59/100
# 52/52 - 3s - loss: 3.0220e-05 - 3s/epoch - 50ms/step
# Epoch 60/100
# 52/52 - 3s - loss: 3.9597e-05 - 3s/epoch - 49ms/step
# Epoch 61/100
# 52/52 - 3s - loss: 3.5980e-05 - 3s/epoch - 50ms/step
# Epoch 62/100
# 52/52 - 3s - loss: 3.7497e-05 - 3s/epoch - 51ms/step
# Epoch 63/100
# 52/52 - 3s - loss: 2.9762e-05 - 3s/epoch - 50ms/step
# Epoch 64/100
# 52/52 - 3s - loss: 2.9571e-05 - 3s/epoch - 50ms/step
# Epoch 65/100
# 52/52 - 3s - loss: 2.9226e-05 - 3s/epoch - 50ms/step
# Epoch 66/100
# 52/52 - 3s - loss: 3.6647e-05 - 3s/epoch - 49ms/step
# Epoch 67/100
# 52/52 - 3s - loss: 3.2537e-05 - 3s/epoch - 50ms/step
# Epoch 68/100
# 52/52 - 3s - loss: 4.0005e-05 - 3s/epoch - 50ms/step
# Epoch 69/100
# 52/52 - 3s - loss: 3.5823e-05 - 3s/epoch - 50ms/step
# Epoch 70/100
# 52/52 - 3s - loss: 3.2174e-05 - 3s/epoch - 52ms/step
# Epoch 71/100
# 52/52 - 4s - loss: 3.1543e-05 - 4s/epoch - 70ms/step
# Epoch 72/100
# 52/52 - 4s - loss: 5.1540e-05 - 4s/epoch - 69ms/step
# Epoch 73/100
# 52/52 - 4s - loss: 3.5290e-05 - 4s/epoch - 68ms/step
# Epoch 74/100
# 52/52 - 4s - loss: 2.9800e-05 - 4s/epoch - 68ms/step
# Epoch 75/100
# 52/52 - 4s - loss: 2.7909e-05 - 4s/epoch - 68ms/step
# Epoch 76/100
# 52/52 - 4s - loss: 2.9305e-05 - 4s/epoch - 68ms/step
# Epoch 77/100
# 52/52 - 4s - loss: 2.7532e-05 - 4s/epoch - 68ms/step
# Epoch 78/100
# 52/52 - 3s - loss: 2.7111e-05 - 3s/epoch - 66ms/step
# Epoch 79/100
# 52/52 - 3s - loss: 2.9715e-05 - 3s/epoch - 53ms/step
# Epoch 80/100
# 52/52 - 3s - loss: 2.9263e-05 - 3s/epoch - 50ms/step
# Epoch 81/100
# 52/52 - 3s - loss: 2.5626e-05 - 3s/epoch - 49ms/step
# Epoch 82/100
# 52/52 - 3s - loss: 3.6596e-05 - 3s/epoch - 50ms/step
# Epoch 83/100
# 52/52 - 3s - loss: 2.7862e-05 - 3s/epoch - 50ms/step
# Epoch 84/100
# 52/52 - 3s - loss: 2.8319e-05 - 3s/epoch - 50ms/step
# Epoch 85/100
# 52/52 - 3s - loss: 2.9639e-05 - 3s/epoch - 50ms/step
# Epoch 86/100
# 52/52 - 3s - loss: 2.4187e-05 - 3s/epoch - 58ms/step
# Epoch 87/100
# 52/52 - 3s - loss: 2.6390e-05 - 3s/epoch - 59ms/step
# Epoch 88/100
# 52/52 - 3s - loss: 3.3730e-05 - 3s/epoch - 64ms/step
# Epoch 89/100
# 52/52 - 3s - loss: 2.8619e-05 - 3s/epoch - 62ms/step
# Epoch 90/100
# 52/52 - 3s - loss: 2.9728e-05 - 3s/epoch - 56ms/step
# Epoch 91/100
# 52/52 - 3s - loss: 2.8337e-05 - 3s/epoch - 52ms/step
# Epoch 92/100
# 52/52 - 3s - loss: 2.8536e-05 - 3s/epoch - 56ms/step
# Epoch 93/100
# 52/52 - 3s - loss: 2.7712e-05 - 3s/epoch - 50ms/step
# Epoch 94/100
# 52/52 - 3s - loss: 2.7980e-05 - 3s/epoch - 50ms/step
# Epoch 95/100
# 52/52 - 3s - loss: 3.0417e-05 - 3s/epoch - 50ms/step
# Epoch 96/100
# 52/52 - 3s - loss: 2.6153e-05 - 3s/epoch - 51ms/step
# Epoch 97/100
# 52/52 - 3s - loss: 2.7703e-05 - 3s/epoch - 50ms/step
# Epoch 98/100
# 52/52 - 3s - loss: 2.9840e-05 - 3s/epoch - 50ms/step
# Epoch 99/100
# 52/52 - 3s - loss: 2.6039e-05 - 3s/epoch - 55ms/step
# Epoch 100/100
# 52/52 - 3s - loss: 2.5896e-05 - 3s/epoch - 51ms/step
# 17/17 [==============================] - 1s 16ms/step
# Epoch 1/100
# 68/68 - 6s - loss: 0.0012 - 6s/epoch - 93ms/step
# Epoch 2/100
# 68/68 - 3s - loss: 1.9675e-04 - 3s/epoch - 41ms/step
# Epoch 3/100
# 68/68 - 3s - loss: 1.6934e-04 - 3s/epoch - 41ms/step
# Epoch 4/100
# 68/68 - 3s - loss: 1.8907e-04 - 3s/epoch - 43ms/step
# Epoch 5/100
# 68/68 - 3s - loss: 1.4358e-04 - 3s/epoch - 40ms/step
# Epoch 6/100
# 68/68 - 3s - loss: 1.5223e-04 - 3s/epoch - 40ms/step
# Epoch 7/100
# 68/68 - 3s - loss: 1.4886e-04 - 3s/epoch - 40ms/step
# Epoch 8/100
# 68/68 - 3s - loss: 1.4315e-04 - 3s/epoch - 40ms/step
# Epoch 9/100
# 68/68 - 3s - loss: 1.2413e-04 - 3s/epoch - 40ms/step
# Epoch 10/100
# 68/68 - 3s - loss: 1.0965e-04 - 3s/epoch - 42ms/step
# Epoch 11/100
# 68/68 - 3s - loss: 1.2370e-04 - 3s/epoch - 51ms/step
# Epoch 12/100
# 68/68 - 4s - loss: 1.0189e-04 - 4s/epoch - 58ms/step
# Epoch 13/100
# 68/68 - 4s - loss: 1.0265e-04 - 4s/epoch - 58ms/step
# Epoch 14/100
# 68/68 - 4s - loss: 9.9943e-05 - 4s/epoch - 56ms/step
# Epoch 15/100
# 68/68 - 4s - loss: 1.1636e-04 - 4s/epoch - 54ms/step
# Epoch 16/100
# 68/68 - 4s - loss: 1.1069e-04 - 4s/epoch - 54ms/step
# Epoch 17/100
# 68/68 - 4s - loss: 9.2516e-05 - 4s/epoch - 61ms/step
# Epoch 18/100
# 68/68 - 4s - loss: 9.6351e-05 - 4s/epoch - 60ms/step
# Epoch 19/100
# 68/68 - 3s - loss: 8.6015e-05 - 3s/epoch - 42ms/step
# Epoch 20/100
# 68/68 - 3s - loss: 8.8383e-05 - 3s/epoch - 39ms/step
# Epoch 21/100
# 68/68 - 3s - loss: 8.1564e-05 - 3s/epoch - 39ms/step
# Epoch 22/100
# 68/68 - 3s - loss: 8.0178e-05 - 3s/epoch - 41ms/step
# Epoch 23/100
# 68/68 - 3s - loss: 8.5979e-05 - 3s/epoch - 40ms/step
# Epoch 24/100
# 68/68 - 3s - loss: 8.7776e-05 - 3s/epoch - 40ms/step
# Epoch 25/100
# 68/68 - 3s - loss: 8.5829e-05 - 3s/epoch - 40ms/step
# Epoch 26/100
# 68/68 - 3s - loss: 7.6543e-05 - 3s/epoch - 39ms/step
# Epoch 27/100
# 68/68 - 3s - loss: 7.4209e-05 - 3s/epoch - 39ms/step
# Epoch 28/100
# 68/68 - 3s - loss: 7.4822e-05 - 3s/epoch - 39ms/step
# Epoch 29/100
# 68/68 - 3s - loss: 7.5557e-05 - 3s/epoch - 39ms/step
# Epoch 30/100
# 68/68 - 3s - loss: 7.3932e-05 - 3s/epoch - 41ms/step
# Epoch 31/100
# 68/68 - 3s - loss: 7.5999e-05 - 3s/epoch - 39ms/step
# Epoch 32/100
# 68/68 - 3s - loss: 7.5234e-05 - 3s/epoch - 39ms/step
# Epoch 33/100
# 68/68 - 3s - loss: 7.9981e-05 - 3s/epoch - 51ms/step
# Epoch 34/100
# 68/68 - 3s - loss: 7.1840e-05 - 3s/epoch - 39ms/step
# Epoch 35/100
# 68/68 - 3s - loss: 6.9087e-05 - 3s/epoch - 39ms/step
# Epoch 36/100
# 68/68 - 3s - loss: 6.4572e-05 - 3s/epoch - 40ms/step
# Epoch 37/100
# 68/68 - 3s - loss: 6.9507e-05 - 3s/epoch - 41ms/step
# Epoch 38/100
# 68/68 - 3s - loss: 6.4058e-05 - 3s/epoch - 40ms/step
# Epoch 39/100
# 68/68 - 3s - loss: 7.7795e-05 - 3s/epoch - 39ms/step
# Epoch 40/100
# 68/68 - 3s - loss: 7.1988e-05 - 3s/epoch - 40ms/step
# Epoch 41/100
# 68/68 - 3s - loss: 7.7266e-05 - 3s/epoch - 39ms/step
# Epoch 42/100
# 68/68 - 3s - loss: 7.3971e-05 - 3s/epoch - 39ms/step
# Epoch 43/100
# 68/68 - 3s - loss: 7.5552e-05 - 3s/epoch - 39ms/step
# Epoch 44/100
# 68/68 - 3s - loss: 7.0212e-05 - 3s/epoch - 40ms/step
# Epoch 45/100
# 68/68 - 3s - loss: 6.7922e-05 - 3s/epoch - 39ms/step
# Epoch 46/100
# 68/68 - 3s - loss: 6.6409e-05 - 3s/epoch - 39ms/step
# Epoch 47/100
# 68/68 - 3s - loss: 7.1212e-05 - 3s/epoch - 39ms/step
# Epoch 48/100
# 68/68 - 3s - loss: 6.9154e-05 - 3s/epoch - 39ms/step
# Epoch 49/100
# 68/68 - 3s - loss: 6.7217e-05 - 3s/epoch - 40ms/step
# Epoch 50/100
# 68/68 - 3s - loss: 7.8093e-05 - 3s/epoch - 39ms/step
# Epoch 51/100
# 68/68 - 3s - loss: 7.1208e-05 - 3s/epoch - 39ms/step
# Epoch 52/100
# 68/68 - 3s - loss: 8.0927e-05 - 3s/epoch - 41ms/step
# Epoch 53/100
# 68/68 - 3s - loss: 6.8308e-05 - 3s/epoch - 40ms/step
# Epoch 54/100
# 68/68 - 3s - loss: 7.6034e-05 - 3s/epoch - 40ms/step
# Epoch 55/100
# 68/68 - 3s - loss: 6.4633e-05 - 3s/epoch - 40ms/step
# Epoch 56/100
# 68/68 - 3s - loss: 7.4746e-05 - 3s/epoch - 40ms/step
# Epoch 57/100
# 68/68 - 3s - loss: 6.6316e-05 - 3s/epoch - 40ms/step
# Epoch 58/100
# 68/68 - 3s - loss: 6.3213e-05 - 3s/epoch - 40ms/step
# Epoch 59/100
# 68/68 - 3s - loss: 7.2408e-05 - 3s/epoch - 41ms/step
# Epoch 60/100
# 68/68 - 3s - loss: 7.7348e-05 - 3s/epoch - 40ms/step
# Epoch 61/100
# 68/68 - 3s - loss: 6.2757e-05 - 3s/epoch - 39ms/step
# Epoch 62/100
# 68/68 - 3s - loss: 5.8224e-05 - 3s/epoch - 40ms/step
# Epoch 63/100
# 68/68 - 3s - loss: 6.5680e-05 - 3s/epoch - 39ms/step
# Epoch 64/100
# 68/68 - 3s - loss: 5.8821e-05 - 3s/epoch - 41ms/step
# Epoch 65/100
# 68/68 - 3s - loss: 6.1364e-05 - 3s/epoch - 39ms/step
# Epoch 66/100
# 68/68 - 3s - loss: 6.1024e-05 - 3s/epoch - 40ms/step
# Epoch 67/100
# 68/68 - 3s - loss: 6.2887e-05 - 3s/epoch - 39ms/step
# Epoch 68/100
# 68/68 - 3s - loss: 6.2901e-05 - 3s/epoch - 39ms/step
# Epoch 69/100
# 68/68 - 3s - loss: 6.4705e-05 - 3s/epoch - 40ms/step
# Epoch 70/100
# 68/68 - 3s - loss: 6.1192e-05 - 3s/epoch - 39ms/step
# Epoch 71/100
# 68/68 - 3s - loss: 6.3277e-05 - 3s/epoch - 40ms/step
# Epoch 72/100
# 68/68 - 3s - loss: 6.9291e-05 - 3s/epoch - 39ms/step
# Epoch 73/100
# 68/68 - 3s - loss: 6.6709e-05 - 3s/epoch - 41ms/step
# Epoch 74/100
# 68/68 - 4s - loss: 7.0455e-05 - 4s/epoch - 53ms/step
# Epoch 75/100
# 68/68 - 3s - loss: 6.2850e-05 - 3s/epoch - 43ms/step
# Epoch 76/100
# 68/68 - 3s - loss: 6.9819e-05 - 3s/epoch - 40ms/step
# Epoch 77/100
# 68/68 - 3s - loss: 6.9361e-05 - 3s/epoch - 43ms/step
# Epoch 78/100
# 68/68 - 3s - loss: 6.5928e-05 - 3s/epoch - 44ms/step
# Epoch 79/100
# 68/68 - 3s - loss: 6.9728e-05 - 3s/epoch - 41ms/step
# Epoch 80/100
# 68/68 - 3s - loss: 5.7920e-05 - 3s/epoch - 40ms/step
# Epoch 81/100
# 68/68 - 3s - loss: 5.9046e-05 - 3s/epoch - 42ms/step
# Epoch 82/100
# 68/68 - 3s - loss: 5.4629e-05 - 3s/epoch - 40ms/step
# Epoch 83/100
# 68/68 - 3s - loss: 6.3231e-05 - 3s/epoch - 40ms/step
# Epoch 84/100
# 68/68 - 3s - loss: 6.3584e-05 - 3s/epoch - 41ms/step
# Epoch 85/100
# 68/68 - 3s - loss: 5.8835e-05 - 3s/epoch - 40ms/step
# Epoch 86/100
# 68/68 - 3s - loss: 5.9481e-05 - 3s/epoch - 41ms/step
# Epoch 87/100
# 68/68 - 3s - loss: 6.1077e-05 - 3s/epoch - 41ms/step
# Epoch 88/100
# 68/68 - 3s - loss: 6.6100e-05 - 3s/epoch - 41ms/step
# Epoch 89/100
# 68/68 - 3s - loss: 5.4101e-05 - 3s/epoch - 40ms/step
# Epoch 90/100
# 68/68 - 3s - loss: 6.2733e-05 - 3s/epoch - 42ms/step
# Epoch 91/100
# 68/68 - 3s - loss: 6.1376e-05 - 3s/epoch - 40ms/step
# Epoch 92/100
# 68/68 - 3s - loss: 6.3145e-05 - 3s/epoch - 40ms/step
# Epoch 93/100
# 68/68 - 3s - loss: 6.4810e-05 - 3s/epoch - 43ms/step
# Epoch 94/100
# 68/68 - 3s - loss: 5.6362e-05 - 3s/epoch - 41ms/step
# Epoch 95/100
# 68/68 - 3s - loss: 5.4784e-05 - 3s/epoch - 40ms/step
# Epoch 96/100
# 68/68 - 3s - loss: 6.1566e-05 - 3s/epoch - 40ms/step
# Epoch 97/100
# 68/68 - 3s - loss: 5.8562e-05 - 3s/epoch - 42ms/step
# Epoch 98/100
# 68/68 - 3s - loss: 6.0092e-05 - 3s/epoch - 40ms/step
# Epoch 99/100
# 68/68 - 3s - loss: 6.1025e-05 - 3s/epoch - 40ms/step
# Epoch 100/100
# 68/68 - 3s - loss: 6.9238e-05 - 3s/epoch - 40ms/step
# 17/17 [==============================] - 1s 16ms/step
# Epoch 1/100
# 85/85 - 8s - loss: 0.0023 - 8s/epoch - 98ms/step
# Epoch 2/100
# 85/85 - 4s - loss: 6.8197e-04 - 4s/epoch - 50ms/step
# Epoch 3/100
# 85/85 - 4s - loss: 6.4345e-04 - 4s/epoch - 51ms/step
# Epoch 4/100
# 85/85 - 4s - loss: 6.0609e-04 - 4s/epoch - 50ms/step
# Epoch 5/100
# 85/85 - 4s - loss: 5.4764e-04 - 4s/epoch - 50ms/step
# Epoch 6/100
# 85/85 - 4s - loss: 5.2045e-04 - 4s/epoch - 49ms/step
# Epoch 7/100
# 85/85 - 4s - loss: 5.6492e-04 - 4s/epoch - 50ms/step
# Epoch 8/100
# 85/85 - 4s - loss: 6.2841e-04 - 4s/epoch - 50ms/step
# Epoch 9/100
# 85/85 - 4s - loss: 5.1119e-04 - 4s/epoch - 50ms/step
# Epoch 10/100
# 85/85 - 4s - loss: 5.3635e-04 - 4s/epoch - 50ms/step
# Epoch 11/100
# 85/85 - 4s - loss: 4.6486e-04 - 4s/epoch - 50ms/step
# Epoch 12/100
# 85/85 - 4s - loss: 4.4728e-04 - 4s/epoch - 50ms/step
# Epoch 13/100
# 85/85 - 4s - loss: 4.1783e-04 - 4s/epoch - 51ms/step
# Epoch 14/100
# 85/85 - 4s - loss: 4.2878e-04 - 4s/epoch - 50ms/step
# Epoch 15/100
# 85/85 - 4s - loss: 4.0055e-04 - 4s/epoch - 50ms/step
# Epoch 16/100
# 85/85 - 4s - loss: 3.5301e-04 - 4s/epoch - 50ms/step
# Epoch 17/100
# 85/85 - 4s - loss: 3.9562e-04 - 4s/epoch - 50ms/step
# Epoch 18/100
# 85/85 - 4s - loss: 4.1247e-04 - 4s/epoch - 50ms/step
# Epoch 19/100
# 85/85 - 4s - loss: 4.3059e-04 - 4s/epoch - 50ms/step
# Epoch 20/100
# 85/85 - 4s - loss: 3.9507e-04 - 4s/epoch - 51ms/step
# Epoch 21/100
# 85/85 - 4s - loss: 3.7612e-04 - 4s/epoch - 50ms/step
# Epoch 22/100
# 85/85 - 4s - loss: 3.5634e-04 - 4s/epoch - 50ms/step
# Epoch 23/100
# 85/85 - 4s - loss: 3.5098e-04 - 4s/epoch - 50ms/step
# Epoch 24/100
# 85/85 - 4s - loss: 2.9745e-04 - 4s/epoch - 50ms/step
# Epoch 25/100
# 85/85 - 4s - loss: 3.0820e-04 - 4s/epoch - 50ms/step
# Epoch 26/100
# 85/85 - 4s - loss: 3.2757e-04 - 4s/epoch - 50ms/step
# Epoch 27/100
# 85/85 - 4s - loss: 3.3586e-04 - 4s/epoch - 51ms/step
# Epoch 28/100
# 85/85 - 4s - loss: 4.3837e-04 - 4s/epoch - 50ms/step
# Epoch 29/100
# 85/85 - 4s - loss: 3.2121e-04 - 4s/epoch - 52ms/step
# Epoch 30/100
# 85/85 - 4s - loss: 3.0572e-04 - 4s/epoch - 52ms/step
# Epoch 31/100
# 85/85 - 4s - loss: 3.1663e-04 - 4s/epoch - 52ms/step
# Epoch 32/100
# 85/85 - 4s - loss: 3.1385e-04 - 4s/epoch - 51ms/step
# Epoch 33/100
# 85/85 - 4s - loss: 3.2501e-04 - 4s/epoch - 50ms/step
# Epoch 34/100
# 85/85 - 4s - loss: 3.1430e-04 - 4s/epoch - 50ms/step
# Epoch 35/100
# 85/85 - 4s - loss: 4.0909e-04 - 4s/epoch - 50ms/step
# Epoch 36/100
# 85/85 - 4s - loss: 2.7289e-04 - 4s/epoch - 50ms/step
# Epoch 37/100
# 85/85 - 4s - loss: 2.7123e-04 - 4s/epoch - 51ms/step
# Epoch 38/100
# 85/85 - 5s - loss: 2.8124e-04 - 5s/epoch - 56ms/step
# Epoch 39/100
# 85/85 - 5s - loss: 2.8488e-04 - 5s/epoch - 64ms/step
# Epoch 40/100
# 85/85 - 6s - loss: 2.9525e-04 - 6s/epoch - 68ms/step
# Epoch 41/100
# 85/85 - 6s - loss: 3.3398e-04 - 6s/epoch - 69ms/step
# Epoch 42/100
# 85/85 - 6s - loss: 3.1881e-04 - 6s/epoch - 70ms/step
# Epoch 43/100
# 85/85 - 6s - loss: 3.5072e-04 - 6s/epoch - 70ms/step
# Epoch 44/100
# 85/85 - 6s - loss: 3.2820e-04 - 6s/epoch - 70ms/step
# Epoch 45/100
# 85/85 - 5s - loss: 3.7804e-04 - 5s/epoch - 60ms/step
# Epoch 46/100
# 85/85 - 4s - loss: 2.7552e-04 - 4s/epoch - 51ms/step
# Epoch 47/100
# 85/85 - 4s - loss: 2.7564e-04 - 4s/epoch - 51ms/step
# Epoch 48/100
# 85/85 - 5s - loss: 3.2029e-04 - 5s/epoch - 57ms/step
# Epoch 49/100
# 85/85 - 4s - loss: 3.8107e-04 - 4s/epoch - 52ms/step
# Epoch 50/100
# 85/85 - 4s - loss: 2.7238e-04 - 4s/epoch - 52ms/step
# Epoch 51/100
# 85/85 - 4s - loss: 3.0488e-04 - 4s/epoch - 53ms/step
# Epoch 52/100
# 85/85 - 4s - loss: 3.2389e-04 - 4s/epoch - 51ms/step
# Epoch 53/100
# 85/85 - 4s - loss: 3.7803e-04 - 4s/epoch - 50ms/step
# Epoch 54/100
# 85/85 - 4s - loss: 2.9339e-04 - 4s/epoch - 50ms/step
# Epoch 55/100
# 85/85 - 4s - loss: 2.6992e-04 - 4s/epoch - 51ms/step
# Epoch 56/100
# 85/85 - 4s - loss: 2.8169e-04 - 4s/epoch - 51ms/step
# Epoch 57/100
# 85/85 - 4s - loss: 3.3793e-04 - 4s/epoch - 51ms/step
# Epoch 58/100
# 85/85 - 4s - loss: 3.5121e-04 - 4s/epoch - 51ms/step
# Epoch 59/100
# 85/85 - 4s - loss: 3.3144e-04 - 4s/epoch - 50ms/step
# Epoch 60/100
# 85/85 - 4s - loss: 2.9866e-04 - 4s/epoch - 50ms/step
# Epoch 61/100
# 85/85 - 4s - loss: 2.8247e-04 - 4s/epoch - 52ms/step
# Epoch 62/100
# 85/85 - 4s - loss: 2.9665e-04 - 4s/epoch - 53ms/step
# Epoch 63/100
# 85/85 - 4s - loss: 2.7100e-04 - 4s/epoch - 52ms/step
# Epoch 64/100
# 85/85 - 4s - loss: 2.9074e-04 - 4s/epoch - 51ms/step
# Epoch 65/100
# 85/85 - 4s - loss: 2.9145e-04 - 4s/epoch - 51ms/step
# Epoch 66/100
# 85/85 - 4s - loss: 2.9543e-04 - 4s/epoch - 51ms/step
# Epoch 67/100
# 85/85 - 4s - loss: 2.8608e-04 - 4s/epoch - 51ms/step
# Epoch 68/100
# 85/85 - 4s - loss: 3.3425e-04 - 4s/epoch - 51ms/step
# Epoch 69/100
# 85/85 - 4s - loss: 3.3001e-04 - 4s/epoch - 51ms/step
# Epoch 70/100
# 85/85 - 4s - loss: 3.4300e-04 - 4s/epoch - 51ms/step
# Epoch 71/100
# 85/85 - 4s - loss: 2.8495e-04 - 4s/epoch - 51ms/step
# Epoch 72/100
# 85/85 - 4s - loss: 2.9146e-04 - 4s/epoch - 52ms/step
# Epoch 73/100
# 85/85 - 4s - loss: 3.7032e-04 - 4s/epoch - 50ms/step
# Epoch 74/100
# 85/85 - 4s - loss: 2.6372e-04 - 4s/epoch - 50ms/step
# Epoch 75/100
# 85/85 - 4s - loss: 2.6733e-04 - 4s/epoch - 52ms/step
# Epoch 76/100
# 85/85 - 4s - loss: 2.6419e-04 - 4s/epoch - 51ms/step
# Epoch 77/100
# 85/85 - 4s - loss: 2.7206e-04 - 4s/epoch - 50ms/step
# Epoch 78/100
# 85/85 - 4s - loss: 2.7248e-04 - 4s/epoch - 51ms/step
# Epoch 79/100
# 85/85 - 4s - loss: 3.1024e-04 - 4s/epoch - 51ms/step
# Epoch 80/100
# 85/85 - 4s - loss: 2.7646e-04 - 4s/epoch - 51ms/step
# Epoch 81/100
# 85/85 - 4s - loss: 2.6865e-04 - 4s/epoch - 52ms/step
# Epoch 82/100
# 85/85 - 4s - loss: 2.8533e-04 - 4s/epoch - 51ms/step
# Epoch 83/100
# 85/85 - 4s - loss: 2.6017e-04 - 4s/epoch - 50ms/step
# Epoch 84/100
# 85/85 - 4s - loss: 2.6849e-04 - 4s/epoch - 51ms/step
# Epoch 85/100
# 85/85 - 4s - loss: 2.6931e-04 - 4s/epoch - 51ms/step
# Epoch 86/100
# 85/85 - 4s - loss: 2.8924e-04 - 4s/epoch - 51ms/step
# Epoch 87/100
# 85/85 - 5s - loss: 2.8191e-04 - 5s/epoch - 59ms/step
# Epoch 88/100
# 85/85 - 6s - loss: 3.0087e-04 - 6s/epoch - 65ms/step
# Epoch 89/100
# 85/85 - 6s - loss: 2.6174e-04 - 6s/epoch - 74ms/step
# Epoch 90/100
# 85/85 - 6s - loss: 2.6720e-04 - 6s/epoch - 71ms/step
# Epoch 91/100
# 85/85 - 6s - loss: 3.4301e-04 - 6s/epoch - 72ms/step
# Epoch 92/100
# 85/85 - 6s - loss: 2.7644e-04 - 6s/epoch - 70ms/step
# Epoch 93/100
# 85/85 - 6s - loss: 3.0486e-04 - 6s/epoch - 72ms/step
# Epoch 94/100
# 85/85 - 5s - loss: 2.6010e-04 - 5s/epoch - 55ms/step
# Epoch 95/100
# 85/85 - 4s - loss: 2.7160e-04 - 4s/epoch - 52ms/step
# Epoch 96/100
# 85/85 - 5s - loss: 2.7470e-04 - 5s/epoch - 57ms/step
# Epoch 97/100
# 85/85 - 5s - loss: 2.3754e-04 - 5s/epoch - 61ms/step
# Epoch 98/100
# 85/85 - 4s - loss: 2.2506e-04 - 4s/epoch - 51ms/step
# Epoch 99/100
# 85/85 - 4s - loss: 2.9765e-04 - 4s/epoch - 52ms/step
# Epoch 100/100
# 85/85 - 4s - loss: 2.4457e-04 - 4s/epoch - 52ms/step
# 17/17 [==============================] - 1s 15ms/step

# %%
avg_mse = np.mean(mse_scores)
avg_mae = np.mean(mae_scores)
avg_rmse = np.mean(rmse_scores)


print(f"Relative Mean Squared Error: {avg_mse:.4f}")
print(f"Relative Mean Absolute Error: {avg_mae:.4f}")
print(f"Relative Root Mean Squared Error: {avg_rmse:.4f}")
# Out:
# Relative Mean Squared Error: 22.6112
# Relative Mean Absolute Error: 2.7351
# Relative Root Mean Squared Error: 3.3567
